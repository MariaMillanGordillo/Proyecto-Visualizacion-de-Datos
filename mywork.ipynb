# %%
# CARGA DE DATOS
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Renewable_Energy.csv')

# %%
# Dividir el dataset en dos según la columna 'Indicator'
grouped_data = data.groupby('Indicator')

# Crear dos datasets separados
generation = grouped_data.get_group('Electricity Generation')
capacity = grouped_data.get_group('Electricity Installed Capacity')

# Eliminar las columnas especificadas de ambos datasets
columns_to_drop = ['Source', 'CTS_Name', 'CTS_Code', 'CTS_Full_Descriptor', 'Indicator']
generation.drop(columns=columns_to_drop, inplace=True)
capacity.drop(columns=columns_to_drop, inplace=True)
# Out:
# /var/folders/k2/p_2k6jgx3836yjfwy9gj_mgc0000gn/T/ipykernel_4673/2051179899.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   generation.drop(columns=columns_to_drop, inplace=True)
# /var/folders/k2/p_2k6jgx3836yjfwy9gj_mgc0000gn/T/ipykernel_4673/2051179899.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   capacity.drop(columns=columns_to_drop, inplace=True)

# %%
# GENERACION DE ENERGIA POR PAIS

# Seleccionar un pais disponible de la lista
paises = data['Country'].unique().tolist()
print(paises)
lista_pais = ['Albania']

# Seleccionar las columnas de energía
years = [f'F{year}' for year in range(2000, 2023)]

for pais in lista_pais:
    # Filtrar los datos para el país seleccionado
    datos_pais = generation[generation['Country'] == pais]
    fig, ax = plt.subplots(nrows=len(datos_pais), ncols=1, figsize=(14, 6 * len(datos_pais)))
    for (i,fila) in enumerate(datos_pais.transpose()):
        energia = datos_pais.loc[fila,years]
        tecnologia = datos_pais.loc[fila,'Technology']
        ax[i].bar([f'{year}' for year in range(2000,2023)],energia)
        ax[i].set_title(f'Electricity Generation in {pais} (2000-2022) - {tecnologia}')
        ax[i].set_xlabel('Year')
        ax[i].set_ylabel('Gigawatt-hours (GWh)')
    plt.show()
# Out:
# ['Advanced Economies', 'Afghanistan, Islamic Rep. of', 'Africa', 'Albania', 'Algeria', 'American Samoa', 'Americas', 'Andorra, Principality of', 'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia, Rep. of', 'Aruba, Kingdom of the Netherlands', 'Asia', 'Australia', 'Austria', 'Azerbaijan, Rep. of', 'Bahamas, The', 'Bahrain, Kingdom of', 'Bangladesh', 'Barbados', 'Belarus, Rep. of', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bonaire, St. Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands', 'Central African Rep.', 'Central Asia', 'Chad', 'Chile', 'China, P.R.: Hong Kong', 'China, P.R.: Mainland', 'Colombia', 'Comoros, Union of the', 'Congo, Dem. Rep. of the', 'Congo, Rep. of', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia, Rep. of', 'Cuba', 'Curaçao, Kingdom of the Netherlands', 'Cyprus'
# ...

# %%
# Graficar los datos por tipo de energía
    for column in generation_albania.columns:
        generation_albania[[column]].plot(kind='bar', figsize=(12, 6), legend=False)
        plt.title(f'Electricity Generation in Albania (2000-2022) - {column}')
        plt.xlabel('Year')
        plt.ylabel('Gigawatt-hours (GWh)')
        plt.show()
